# %% [markdown]
# <a href="https://colab.research.google.com/github/gumdropsteve/intro_to_python/blob/main/day_06/00_basic_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro to Pandas

# %%
import pandas as pd

pd.read_csv('las_vegas_super_hosts_2021-01-09.csv')
# Out:
#                                    url  \
# 0    https://airbnb.com/rooms/44416011
# 1    https://airbnb.com/rooms/21055421
# 2    https://airbnb.com/rooms/46263193
# 3    https://airbnb.com/rooms/22951918
# 4    https://airbnb.com/rooms/37301916
# ..                                 ...
# 295  https://airbnb.com/rooms/47527391
# 296  https://airbnb.com/rooms/46281494
# 297  https://airbnb.com/rooms/34249991
# 298  https://airbnb.com/rooms/17012020
# 299  https://airbnb.com/rooms/42388610
#
#                                                  title  \
# 0                                            Eggeman 8
# 1                 Private suite with private bathroom.
# 2           Master bedroom in a new, CLEAN, safe home!
# 3           Location! Coffee Condo! South Point Casino
# 4    Private room, Pool, 4 miles from Convention Ce...
# ..                                                 ...
# 295   Las Vegas 2 bedroom 1.5 bath Apartment 2nd floor
# ...

# %% [markdown]
# #### Change the Number of Rows Displayed

# %%
# https://stackoverflow.com/questions/16424493/pandas-setting-no-of-max-rows
pd.set_option('display.max_rows', 300)

# %%
pd.read_csv('las_vegas_super_hosts_2021-01-09.csv')
# Out:
#                                    url  \
# 0    https://airbnb.com/rooms/44416011
# 1    https://airbnb.com/rooms/21055421
# 2    https://airbnb.com/rooms/46263193
# 3    https://airbnb.com/rooms/22951918
# 4    https://airbnb.com/rooms/37301916
# 5    https://airbnb.com/rooms/37470745
# 6    https://airbnb.com/rooms/44685536
# 7     https://airbnb.com/rooms/6328454
# 8    https://airbnb.com/rooms/45928688
# 9    https://airbnb.com/rooms/46526660
# 10   https://airbnb.com/rooms/37882812
# 11   https://airbnb.com/rooms/22294103
# 12   https://airbnb.com/rooms/30269388
# 13   https://airbnb.com/rooms/47152450
# 14   https://airbnb.com/rooms/22329657
# 15   https://airbnb.com/rooms/44137284
# 16   https://airbnb.com/rooms/38798146
# 17   https://airbnb.com/rooms/32843627
# 18   https://airbnb.com/rooms/47329173
# 19   https://airbnb.com/rooms/43469550
# 20   https://airbnb.com/rooms/42159813
# 21   https://airbnb.com/rooms/43469550
# 22   https://airbnb.com/rooms/28127049
# ...

# %%
pd.set_option('display.max_rows', 10)

# %% [markdown]
# # Things in Pandas
# - DataFrame
# - Series

# %%
type(pd.read_csv('las_vegas_super_hosts_2021-01-09.csv'))
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv('las_vegas_super_hosts_2021-01-09.csv')

df['type']
# Out:
# 0             Entire condominium
# 1                   Private room
# 2                   Private room
# 3               Entire townhouse
# 4                   Private room
#                  ...
# 295             Entire apartment
# 296             Entire apartment
# 297    Entire serviced apartment
# 298                 Private room
# 299                 Private room
# Name: type, Length: 300, dtype: object

# %%
type(df['type'])
# Out:
# pandas.core.series.Series

# %%
# show me the first 5 rows
df.head()
# Out:
#                                  url  \
# 0  https://airbnb.com/rooms/44416011
# 1  https://airbnb.com/rooms/21055421
# 2  https://airbnb.com/rooms/46263193
# 3  https://airbnb.com/rooms/22951918
# 4  https://airbnb.com/rooms/37301916
#
#                                                title                type  \
# 0                                          Eggeman 8  Entire condominium
# 1               Private suite with private bathroom.        Private room
# 2         Master bedroom in a new, CLEAN, safe home!        Private room
# 3         Location! Coffee Condo! South Point Casino    Entire townhouse
# 4  Private room, Pool, 4 miles from Convention Ce...        Private room
#
#     location  guests  bedrooms  beds  is_studio  baths  half_baths  ...  \
# 0  Las Vegas     3.0         2   3.0      False    1.5         NaN  ...
# 1  Las Vegas     NaN         1   NaN      False    NaN         NaN  ...
# 2  Las Vegas     NaN         1   NaN      False    1.5         NaN  ...
# ...

# %%
df['type'].head()
# Out:
# 0    Entire condominium
# 1          Private room
# 2          Private room
# 3      Entire townhouse
# 4          Private room
# Name: type, dtype: object

# %%
# show me the last 5
df['type'].tail()
# Out:
# 295             Entire apartment
# 296             Entire apartment
# 297    Entire serviced apartment
# 298                 Private room
# 299                 Private room
# Name: type, dtype: object

# %%
# pull multiple columns
df[['type', 'location']]
# Out:
#                           type   location
# 0           Entire condominium  Las Vegas
# 1                 Private room  Las Vegas
# 2                 Private room  Las Vegas
# 3             Entire townhouse  Las Vegas
# 4                 Private room  Las Vegas
# ..                         ...        ...
# 295           Entire apartment  Las Vegas
# 296           Entire apartment  Las Vegas
# 297  Entire serviced apartment  Las Vegas
# 298               Private room  Las Vegas
# 299               Private room  Las Vegas
#
# [300 rows x 2 columns]

# %%
df.type
# Out:
# 0             Entire condominium
# 1                   Private room
# 2                   Private room
# 3               Entire townhouse
# 4                   Private room
#                  ...
# 295             Entire apartment
# 296             Entire apartment
# 297    Entire serviced apartment
# 298                 Private room
# 299                 Private room
# Name: type, Length: 300, dtype: object

# %%
df.type.sample(10)
# Out:
# 25              Entire apartment
# 207           Entire condominium
# 82                  Private room
# 274           Entire guest suite
# 215                 Entire house
# 254                 Private room
# 243             Entire apartment
# 189                 Private room
# 159    Entire serviced apartment
# 205                 Private room
# Name: type, dtype: object

# %%
df['type'].sample(10)
# Out:
# 152          Private room
# 125          Private room
# 174          Private room
# 181          Private room
# 266    Entire condominium
# 247          Private room
# 190          Private room
# 15           Private room
# 47           Private room
# 193           Entire loft
# Name: type, dtype: object

# %%
df.sample(10)
# Out:
#                                    url  \
# 9    https://airbnb.com/rooms/46526660
# 38   https://airbnb.com/rooms/13516266
# 183  https://airbnb.com/rooms/45843899
# 40   https://airbnb.com/rooms/47152450
# 95   https://airbnb.com/rooms/45413763
# 68   https://airbnb.com/rooms/46511934
# 150  https://airbnb.com/rooms/45723670
# 229  https://airbnb.com/rooms/40657643
# 151  https://airbnb.com/rooms/20943365
# 109  https://airbnb.com/rooms/45403627
#
#                                                  title                type  \
# 9                    VEGAS Condo 1.5 blocks from strip  Entire condominium
# 38       Private corner apartment 7 minutes from Strip    Entire apartment
# 183                                Quaint Private room        Private room
# 40     Bohemian Bunk - nice quiet place next to a park        Private room
# 95        Large King Size Bedroom Suite w/ bathroom/TV        Private room
# 68                                     Golden Treasure    Entire apartment
# ...

# %% [markdown]
# ## Making Pandas Data Objects

# %%
pd.Series()
# Out:
# <ipython-input-16-fa15c544da3b>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   pd.Series()
# Series([], dtype: float64)

# %%
# series are 1D
pd.Series([1, 2, 3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series([i for i in range(100)])
# Out:
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
#       ..
# 95    95
# 96    96
# 97    97
# 98    98
# 99    99
# Length: 100, dtype: int64

# %%
pd.Series(['a', 'b', 'c'])
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series(['a', 'b', 'c', 1, 2, 3])
# Out:
# 0    a
# 1    b
# 2    c
# 3    1
# 4    2
# 5    3
# dtype: object

# %% [markdown]
# DataFrames...

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.DataFrame([1, 2, 3])
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
pd.DataFrame([[1, 2, 3], [3, 2, 1]])
# Out:
#    0  1  2
# 0  1  2  3
# 1  3  2  1

# %%
pd.DataFrame([[1, 2, 3], [3, 2, 1]], columns=['a', 'b', 'c'] )
# Out:
#    a  b  c
# 0  1  2  3
# 1  3  2  1

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df['a'] = [1, 2, 3]

df
# Out:
#    a
# 0  1
# 1  2
# 2  3

# %%
df['b'] = [3, 2, 1]
df['c'] = [1.1, 2.1, 3.1]

df
# Out:
#    a  b    c
# 0  1  3  1.1
# 1  2  2  2.1
# 2  3  1  3.1

# %%
pd.DataFrame([pd.Series(['a', 'b', 'c']), pd.Series(['x', 'y', 'z'])])
# Out:
#    0  1  2
# 0  a  b  c
# 1  x  y  z

# %%
pd.DataFrame([pd.Series(['a', 'b', 'c']), pd.Series(['x', 'y', 'z'])])[0]
# Out:
# 0    a
# 1    x
# Name: 0, dtype: object

# %% [markdown]
# ## Getting Specific Values

# %%
df = pd.read_csv('austin_super_hosts_2021-01-09.csv')

df
# Out:
#                                        url  \
# 0        https://airbnb.com/rooms/47467005
# 1        https://airbnb.com/rooms/47452916
# 2        https://airbnb.com/rooms/44390548
# 3        https://airbnb.com/rooms/45750357
# 4        https://airbnb.com/rooms/47328333
# ..                                     ...
# 295  https://airbnb.com/rooms/plus/5601570
# 296      https://airbnb.com/rooms/19159372
# 297      https://airbnb.com/rooms/46992522
# 298      https://airbnb.com/rooms/45974888
# 299      https://airbnb.com/rooms/47079212
#
#                                                  title  \
# 0        Professionally maintained apt | 2BR in Austin
# 1                     Relax in comfort | 1BR in Austin
# 2    Brand NEW Garage Apartment blocks from Downtow...
# 3    MONTH-TO-MONTH Furnished Rental near SoCo - El...
# 4             Well-kept apartment home | 1BR in Austin
# ..                                                 ...
# ...

# %%
df['location'][2]
# Out:
# 'East Downtown'

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html
# Purely integer-location based indexing for selection by position.
df.iloc[2]
# Out:
# url                                    https://airbnb.com/rooms/44390548
# title                  Brand NEW Garage Apartment blocks from Downtow...
# type                                                        Entire house
# location                                                   East Downtown
# guests                                                               2.0
#                                              ...
# heating_bool                                                         NaN
# waterfront_bool                                                      NaN
# dishwasher_bool                                                      NaN
# beachfront_bool                                                      NaN
# ski_in_ski_out_bool                                                  NaN
# Name: 2, Length: 33, dtype: object

# %%
df.iloc[2:5]
# Out:
#                                  url  \
# 2  https://airbnb.com/rooms/44390548
# 3  https://airbnb.com/rooms/45750357
# 4  https://airbnb.com/rooms/47328333
#
#                                                title  \
# 2  Brand NEW Garage Apartment blocks from Downtow...
# 3  MONTH-TO-MONTH Furnished Rental near SoCo - El...
# 4           Well-kept apartment home | 1BR in Austin
#
#                         type       location  guests  bedrooms  beds  \
# 2               Entire house  East Downtown     2.0       1.0   2.0
# 3               Entire house       McKinney     2.0       2.0   2.0
# 4  Entire serviced apartment     North Loop     NaN       1.0   NaN
#
#    is_studio  baths  half_baths  ...  kitchen_bool  breakfast_bool  \
# 2      False    1.0         NaN  ...          True             NaN
# 3      False    1.0         NaN  ...           NaN             NaN
# 4      False    1.0         NaN  ...           NaN             NaN
#
# ...

# %%
df.iloc[2:5][['type', 'location', 'price']]
# Out:
#                         type       location  price
# 2               Entire house  East Downtown   72.0
# 3               Entire house       McKinney   89.0
# 4  Entire serviced apartment     North Loop   92.0

# %%
df = pd.read_csv('https://github.com/gumdropsteve/datasets/raw/master/stocks/AAPL.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-11-17   10.757143   10.856786   10.634286   10.732142    9.182909
# 1     2010-11-18   10.900000   11.059643   10.881785   11.015357    9.425239
# 2     2010-11-19   10.998929   11.014286   10.901428   10.954643    9.373289
# 3     2010-11-22   10.952857   11.191428   10.923928   11.191428    9.575893
# 4     2010-11-23   11.087500   11.133928   10.948571   11.026072    9.434405
# ...          ...         ...         ...         ...         ...         ...
# 2512  2020-11-10  115.550003  117.589996  114.129997  115.970001  115.970001
# 2513  2020-11-11  117.190002  119.629997  116.440002  119.489998  119.489998
# 2514  2020-11-12  119.620003  120.529999  118.570000  119.209999  119.209999
# 2515  2020-11-13  119.440002  119.669998  117.870003  119.260002  119.260002
# 2516  2020-11-16  118.919998  120.989998  118.150002  120.300003  120.300003
#
#          Volume
# 0     479449600
# ...

# %%
df[['Open', 'Close']].loc[df['Date'] > '2012-11-17']
# Out:
#             Open       Close
# 504    19.311071   20.204643
# 505    20.425358   20.032499
# 506    20.151785   20.060715
# 507    20.256071   20.410715
# 508    20.567858   21.054644
# ...          ...         ...
# 2512  115.550003  115.970001
# 2513  117.190002  119.489998
# 2514  119.620003  119.209999
# 2515  119.440002  119.260002
# 2516  118.919998  120.300003
#
# [2013 rows x 2 columns]

# %% [markdown]
# ## Write / Read

# %%
df.to_csv('test.csv')

# %%
pd.read_csv('test.csv')
# Out:
#       Unnamed: 0        Date        Open        High         Low       Close  \
# 0              0  2010-11-17   10.757143   10.856786   10.634286   10.732142
# 1              1  2010-11-18   10.900000   11.059643   10.881785   11.015357
# 2              2  2010-11-19   10.998929   11.014286   10.901428   10.954643
# 3              3  2010-11-22   10.952857   11.191428   10.923928   11.191428
# 4              4  2010-11-23   11.087500   11.133928   10.948571   11.026072
# ...          ...         ...         ...         ...         ...         ...
# 2512        2512  2020-11-10  115.550003  117.589996  114.129997  115.970001
# 2513        2513  2020-11-11  117.190002  119.629997  116.440002  119.489998
# 2514        2514  2020-11-12  119.620003  120.529999  118.570000  119.209999
# 2515        2515  2020-11-13  119.440002  119.669998  117.870003  119.260002
# 2516        2516  2020-11-16  118.919998  120.989998  118.150002  120.300003
#
#        Adj Close     Volume
# ...

# %%
df.to_csv('test.csv', index=False)

# %%
pd.read_csv('test.csv')
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-11-17   10.757143   10.856786   10.634286   10.732142    9.182909
# 1     2010-11-18   10.900000   11.059643   10.881785   11.015357    9.425239
# 2     2010-11-19   10.998929   11.014286   10.901428   10.954643    9.373289
# 3     2010-11-22   10.952857   11.191428   10.923928   11.191428    9.575893
# 4     2010-11-23   11.087500   11.133928   10.948571   11.026072    9.434405
# ...          ...         ...         ...         ...         ...         ...
# 2512  2020-11-10  115.550003  117.589996  114.129997  115.970001  115.970001
# 2513  2020-11-11  117.190002  119.629997  116.440002  119.489998  119.489998
# 2514  2020-11-12  119.620003  120.529999  118.570000  119.209999  119.209999
# 2515  2020-11-13  119.440002  119.669998  117.870003  119.260002  119.260002
# 2516  2020-11-16  118.919998  120.989998  118.150002  120.300003  120.300003
#
#          Volume
# 0     479449600
# ...

# %%
df.to_parquet('test.parquet', index=False)

# %%
pd.read_parquet('test.parquet')
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-11-17   10.757143   10.856786   10.634286   10.732142    9.182909
# 1     2010-11-18   10.900000   11.059643   10.881785   11.015357    9.425239
# 2     2010-11-19   10.998929   11.014286   10.901428   10.954643    9.373289
# 3     2010-11-22   10.952857   11.191428   10.923928   11.191428    9.575893
# 4     2010-11-23   11.087500   11.133928   10.948571   11.026072    9.434405
# ...          ...         ...         ...         ...         ...         ...
# 2512  2020-11-10  115.550003  117.589996  114.129997  115.970001  115.970001
# 2513  2020-11-11  117.190002  119.629997  116.440002  119.489998  119.489998
# 2514  2020-11-12  119.620003  120.529999  118.570000  119.209999  119.209999
# 2515  2020-11-13  119.440002  119.669998  117.870003  119.260002  119.260002
# 2516  2020-11-16  118.919998  120.989998  118.150002  120.300003  120.300003
#
#          Volume
# 0     479449600
# ...

# %% [markdown]
# ### Dictionary

# %%
population_dict = {'California': 38332521,
                   'Texas': 26448193,
                   'New York': 19651127,
                   'Florida': 19552860,
                   'Illinois': 12882135}
population = pd.Series(population_dict)
population
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
area_dict = {'California': 423967, 'Texas': 695662, 'New York': 141297,
             'Florida': 170312, 'Illinois': 149995}
area = pd.Series(area_dict)
area
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# dtype: int64

# %%
area_dict
# Out:
# {'California': 423967,
#  'Texas': 695662,
#  'New York': 141297,
#  'Florida': 170312,
#  'Illinois': 149995}

# %%
area_dict['a'] = 4352

area_dict
# Out:
# {'California': 423967,
#  'Texas': 695662,
#  'New York': 141297,
#  'Florida': 170312,
#  'Illinois': 149995,
#  'a': 4352}

# %%
pd.Series(area_dict)
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# a               4352
# dtype: int64

# %%
pd.DataFrame(pd.Series(area_dict))
# Out:
#                  0
# California  423967
# Texas       695662
# New York    141297
# Florida     170312
# Illinois    149995
# a             4352

# %% [markdown]
# ## Examining Data

# %%
df = pd.read_csv('texas_super_hosts_2021-01-09.csv')

df.type.unique()
# Out:
# array(['Tiny house', 'Treehouse', 'Earth house', 'Entire cabin',
#        'Entire bungalow', 'Entire apartment', 'Entire house',
#        'Entire serviced apartment', 'Camper/RV', 'Entire guesthouse',
#        'Dome house', 'Entire cottage', 'Tent', 'Entire bed and breakfast',
#        'Private room', 'Yurt', 'Entire guest suite', 'Farm stay', 'Boat',
#        'Entire townhouse', 'Room', 'Entire loft', 'Entire condominium',
#        'Entire villa', 'Hotel room', 'Tipi'], dtype=object)

# %%
df['type'].unique()
# Out:
# array(['Tiny house', 'Treehouse', 'Earth house', 'Entire cabin',
#        'Entire bungalow', 'Entire apartment', 'Entire house',
#        'Entire serviced apartment', 'Camper/RV', 'Entire guesthouse',
#        'Dome house', 'Entire cottage', 'Tent', 'Entire bed and breakfast',
#        'Private room', 'Yurt', 'Entire guest suite', 'Farm stay', 'Boat',
#        'Entire townhouse', 'Room', 'Entire loft', 'Entire condominium',
#        'Entire villa', 'Hotel room', 'Tipi'], dtype=object)

# %%
df.loc[df['type']=='Boat']
# Out:
#                                   url  \
# 59  https://airbnb.com/rooms/16567297
#
#                                               title  type   location  guests  \
# 59  Rondavous Land Yacht - Tin Valley Retro Rentals  Boat  Terlingua     NaN
#
#     bedrooms  beds  is_studio  baths  half_baths  ...  kitchen_bool  \
# 59         1   NaN      False    1.0         NaN  ...          True
#
#     breakfast_bool  elevator_bool  washer_bool dryer_bool heating_bool  \
# 59             NaN            NaN          NaN        NaN          1.0
#
#    waterfront_bool dishwasher_bool beachfront_bool  ski_in_ski_out_bool
# 59             NaN             NaN             NaN                  NaN
#
# [1 rows x 33 columns]

# %%
df.loc[df['type']=='Boat']['price']
# Out:
# 59    85.0
# Name: price, dtype: float64

# %%
df.loc[df['type']=='Boat']['url']
# Out:
# 59    https://airbnb.com/rooms/16567297
# Name: url, dtype: object

# %%
df.loc[df['type']=='Dome house']
# Out:
#                                   url  \
# 16    https://airbnb.com/rooms/457547
# 60  https://airbnb.com/rooms/43315024
#
#                                                 title        type  \
# 16         Terluna: Off-grid Adobe Dome near Big Bend  Dome house
# 60  Travis - Modern Tiny House - Tom Dooley’s Hideout  Dome house
#
#             location  guests  bedrooms  beds  is_studio  baths  half_baths  \
# 16         Terlingua     NaN         1   NaN      False    NaN         0.0
# 60  Dripping Springs     2.0         1   2.0      False    1.0         NaN
#
#     ...  kitchen_bool  breakfast_bool  elevator_bool  washer_bool dryer_bool  \
# 16  ...          True             NaN            NaN          NaN        NaN
# 60  ...           NaN             NaN            NaN          NaN        NaN
#
#    heating_bool waterfront_bool dishwasher_bool beachfront_bool  \
# 16          NaN             NaN             NaN             NaN
# ...

# %%
df.loc[df['type']=='Dome house']['price']
# Out:
# 16    107.0
# 60    109.0
# Name: price, dtype: float64

# %%
df.loc[df['type']=='Dome house']['url']
# Out:
# 16      https://airbnb.com/rooms/457547
# 60    https://airbnb.com/rooms/43315024
# Name: url, dtype: object

# %%
df.loc[df['type']=='Yurt']['url']
# Out:
# 37    https://airbnb.com/rooms/40119194
# Name: url, dtype: object

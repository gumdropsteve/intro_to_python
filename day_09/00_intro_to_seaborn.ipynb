# %% [markdown]
# <a href="https://colab.research.google.com/github/gumdropsteve/intro_to_python/blob/main/day_09/00_intro_to_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro to seaborn: statistical data visualization
# https://seaborn.pydata.org | [Turorials](https://seaborn.pydata.org/tutorial.html) | [Color Options](https://seaborn.pydata.org/tutorial/color_palettes.html) | [Iris Dataset](https://en.wikipedia.org/wiki/Iris_flower_data_set)

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/gumdropsteve/datasets/master/iris.csv')

df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  target
# 0             5.1          3.5           1.4          0.2     setosa       0
# 1             4.9          3.0           1.4          0.2     setosa       0
# 2             4.7          3.2           1.3          0.2     setosa       0
# 3             4.6          3.1           1.5          0.2     setosa       0
# 4             5.0          3.6           1.4          0.2     setosa       0
# ..            ...          ...           ...          ...        ...     ...
# 145           6.7          3.0           5.2          2.3  virginica       2
# 146           6.3          2.5           5.0          1.9  virginica       2
# 147           6.5          3.0           5.2          2.0  virginica       2
# 148           6.2          3.4           5.4          2.3  virginica       2
# 149           5.9          3.0           5.1          1.8  virginica       2
#
# [150 rows x 6 columns]

# %% [markdown]
# #### pairwise data relationships
# https://seaborn.pydata.org/tutorial/axis_grids.html

# %%
import seaborn as sns

# load in iris datset from seaborn
iris = sns.load_dataset("iris")

# make a parigrid
g = sns.PairGrid(iris)

# plot scatter plots
g.map(sns.scatterplot)

# %%
# load in iris datset from seaborn
iris = sns.load_dataset("iris")

# make a parigrid
g = sns.PairGrid(iris, hue='species')

# plot scatter plots
g.map(sns.scatterplot)

# %%
# what's a parigrid?
sns.PairGrid(iris)

# %%
# seaborn provided iris dataset
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# our iris dataset
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  target
# 0             5.1          3.5           1.4          0.2     setosa       0
# 1             4.9          3.0           1.4          0.2     setosa       0
# 2             4.7          3.2           1.3          0.2     setosa       0
# 3             4.6          3.1           1.5          0.2     setosa       0
# 4             5.0          3.6           1.4          0.2     setosa       0
# ..            ...          ...           ...          ...        ...     ...
# 145           6.7          3.0           5.2          2.3  virginica       2
# 146           6.3          2.5           5.0          1.9  virginica       2
# 147           6.5          3.0           5.2          2.0  virginica       2
# 148           6.2          3.4           5.4          2.3  virginica       2
# 149           5.9          3.0           5.1          1.8  virginica       2
#
# [150 rows x 6 columns]

# %%
sns.PairGrid(df)

# %%
import seaborn as sns

g = sns.PairGrid(df, hue='species')

g.map(sns.scatterplot)

# %% [markdown]
# ## Using Random Data (blobs.csv)

# %%
import pandas as pd

blobs = pd.read_csv('https://github.com/gumdropsteve/datasets/raw/master/blobs.csv')

blobs
# Out:
#                a         b          c         d         e         f  \
# 0       5.146145 -0.738457   4.328718  7.477846  9.491392  5.983533
# 1       4.123623  0.766847  10.381310  2.174481 -2.907114  2.688540
# 2      -3.784730 -2.025454   4.747376 -9.562845  3.445690  3.132766
# 3       5.143979 -0.419808   3.982430  8.339258  9.473218  7.309315
# 4      -5.599334 -2.974889  -9.162853  3.316089  0.340652 -5.733498
# ...          ...       ...        ...       ...       ...       ...
# 136067 -0.407431  4.901098   0.853544  0.428408 -0.427208  3.402264
# 136068 -4.236912 -2.414742  -8.046018  4.683777  0.558284 -5.370067
# 136069 -0.026303  4.330893   1.797365  1.359152 -1.685891  3.101899
# 136070  0.236345  3.344960   3.459480  2.973486 -2.281698  2.975151
# 136071 -0.783559  0.426375   3.436725 -9.776984  0.780760  4.009945
#
#                 g         h          i         j  ...        ff         gg  \
# ...

# %%
# g = sns.PairGrid(blobs)

# g.map(sns.scatterplot)

# %%
# above takes too long to run... too much data for my system with seaborn
blobs_small = blobs.sample(1000)

del blobs

# %% [markdown]
# #### Is there a time difference between adding a hue and not adding a hue

# %%
# %%time
# pick the columns I want to focus on
blobs_small_2 = blobs_small[['a', 'b', 'c', 'd']]

# make the parigred
g = sns.PairGrid(blobs_small_2)

# apply the scatter plots
g.map(sns.scatterplot)
# Out:
# Wall time: 1.93 s

# %%
blobs_adjusted = blobs_small[['a', 'b', 'c', 'd', 'Y']]

blobs_adjusted['Y'] = blobs_adjusted['Y'].astype('str')
# Out:
# <ipython-input-13-e3694d6860c2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   blobs_adjusted['Y'] = blobs_adjusted['Y'].astype('str')

# %%
# %%time
# pick the columns I want to focus on
blobs_small_2 = blobs_adjusted[['a', 'b', 'c', 'd', 'Y']]

# make the parigred
g = sns.PairGrid(blobs_small_2, hue='Y')

# apply the scatter plots
g.map(sns.scatterplot)
# Out:
# Wall time: 3.03 s

# %% [markdown]
# ## You can do more with PairGrid

# %%
# with iris
g = sns.PairGrid(iris)

g.map_diag(sns.histplot)

g.map_offdiag(sns.scatterplot)

# %%
# %%time
# with iris
g = sns.PairGrid(iris, hue='species')

g.map_diag(sns.histplot)

g.map_offdiag(sns.scatterplot)
# Out:
# Wall time: 3.13 s

# %%
g = sns.PairGrid(blobs_adjusted, hue='Y')

g.map_diag(sns.histplot)

g.map_offdiag(sns.scatterplot)

# %% [markdown]
# How long did that take??

# %%
# %%time
g = sns.PairGrid(blobs_adjusted, hue='Y')

g.map_diag(sns.histplot)

g.map_offdiag(sns.scatterplot)
# Out:
# Wall time: 4.58 s
